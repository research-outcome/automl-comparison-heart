# %% [markdown]
# # SETUP

# %% [markdown]
# IMPORT FILES AND LIBRARIES

# %%
# import libraries
from google.colab import files
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import scipy as sp
from scipy import stats
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 # import libraries
# ----> 2 from google.colab import files
#       3 import pandas as pd
#       4 import numpy as np
#
# ModuleNotFoundError: No module named 'google'

# %%
# upload UCI files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f744153c-d503-4477-8b0b-155b9f65bc98" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f744153c-d503-4477-8b0b-155b9f65bc98">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# upload Statlog file
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d49b7ba9-82bf-4eb8-8ae2-5306cdd1e470" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d49b7ba9-82bf-4eb8-8ae2-5306cdd1e470">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
cleveland_data.head()
# Out:
#                                                    0
# 0  age\tsex\tcp\ttrestbps\tchol\tfbs\trestecg\tth...
# 1  63\t1\t1\t145\t233\t1\t2\t150\t0\t2.3\t3\t0\t6\t0
# 2  67\t1\t4\t160\t286\t0\t2\t108\t1\t1.5\t2\t3\t3\t2
# 3  67\t1\t4\t120\t229\t0\t2\t129\t1\t2.6\t2\t2\t7\t1
# 4  37\t1\t3\t130\t250\t0\t0\t187\t0\t3.5\t3\t0\t3\t0

# %%
# load Cleveland datafile
cleveland_csv_path = "processed.cleveland.data"
cleveland_data = pd.read_csv(cleveland_csv_path, header = None)
# assign column names
cleveland_data.set_axis(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs',
                  'restecg', 'thalach', 'exang', 'oldpeak', 'slope',
                  'ca', 'thal', 'num'], axis = 1, inplace = True)

# %%
# load Switzerland datafile
switzerland_csv_path = "processed.switzerland.data"
switzerland_data = pd.read_csv(switzerland_csv_path, header = None)
# assign column names
switzerland_data.set_axis(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs',
                  'restecg', 'thalach', 'exang', 'oldpeak', 'slope',
                  'ca', 'thal', 'num'], axis = 1, inplace = True)

# %%
# load VA datafile
va_csv_path = "processed.va.data"
va_data = pd.read_csv(va_csv_path, header = None)
# assign column names
va_data.set_axis(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs',
                  'restecg', 'thalach', 'exang', 'oldpeak', 'slope',
                  'ca', 'thal', 'num'], axis = 1, inplace = True)

# %%
# load Hungarian datafile
hungarian_csv_path = "reprocessed.hungarian.data"
hungarian_data = pd.read_csv(hungarian_csv_path, delimiter = ' ', header = None)
# assign column names
hungarian_data.set_axis(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs',
                  'restecg', 'thalach', 'exang', 'oldpeak', 'slope',
                  'ca', 'thal', 'num'], axis = 1, inplace = True)

# %%
# load Statlog datafile
statlog_csv_path = "heart.dat"
statlog_data = pd.read_csv(statlog_csv_path, delimiter = ' ', header = None)
# assign column names
statlog_data.set_axis(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs',
                  'restecg', 'thalach', 'exang', 'oldpeak', 'slope',
                  'ca', 'thal', 'num'], axis = 1, inplace = True)
# same attributes in same order as other four datasets
# cp has four values but aren't defined in documentation

# %% [markdown]
# # CLEVELAND

# %% [markdown]
# ## ALL DATA

# %% [markdown]
# ### BASIC CLEVELAND INFO

# %%
cleveland_data.head()
# Out:
#     age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0  63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1  67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2  67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3  37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4  41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
#
#    slope   ca thal  num
# 0    3.0  0.0  6.0    0
# 1    2.0  3.0  3.0    2
# 2    2.0  2.0  7.0    1
# 3    3.0  0.0  3.0    0
# 4    1.0  0.0  3.0    0

# %%
# basic column info
cleveland_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    float64
#  1   sex       303 non-null    float64
#  2   cp        303 non-null    float64
#  3   trestbps  303 non-null    float64
#  4   chol      303 non-null    float64
#  5   fbs       303 non-null    float64
#  6   restecg   303 non-null    float64
#  7   thalach   303 non-null    float64
#  8   exang     303 non-null    float64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    float64
#  11  ca        303 non-null    object
#  12  thal      303 non-null    object
#  13  num       303 non-null    int64
# dtypes: float64(11), int64(1), object(2)
# memory usage: 33.3+ KB

# %%
# basic numeric statistics
cleveland_data.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.438944    0.679868    3.158416  131.689769  246.693069    0.148515
# std      9.038662    0.467299    0.960126   17.599748   51.776918    0.356198
# min     29.000000    0.000000    1.000000   94.000000  126.000000    0.000000
# 25%     48.000000    0.000000    3.000000  120.000000  211.000000    0.000000
# 50%     56.000000    1.000000    3.000000  130.000000  241.000000    0.000000
# 75%     61.000000    1.000000    4.000000  140.000000  275.000000    0.000000
# max     77.000000    1.000000    4.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope         num
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.990099  149.607261    0.326733    1.039604    1.600660    0.937294
# ...

# %% [markdown]
# ### VALUE COUNTS

# %%
cleveland_data.age.value_counts()
# age histogram may be good
# Out:
# 58.0    19
# 57.0    17
# 54.0    16
# 59.0    14
# 52.0    13
# 60.0    12
# 51.0    12
# 56.0    11
# 62.0    11
# 44.0    11
# 64.0    10
# 41.0    10
# 67.0     9
# 63.0     9
# 42.0     8
# 43.0     8
# 45.0     8
# 53.0     8
# 55.0     8
# 61.0     8
# 65.0     8
# 50.0     7
# 66.0     7
# 48.0     7
# 46.0     7
# 47.0     5
# 49.0     5
# 70.0     4
# 68.0     4
# 35.0     4
# 39.0     4
# 69.0     3
# 71.0     3
# 40.0     3
# 34.0     2
# 37.0     2
# 38.0     2
# 29.0     1
# 77.0     1
# 74.0     1
# 76.0     1
# Name: age, dtype: int64

# %%
cleveland_data.sex.value_counts()
# twice as many men as women
# Out:
# 1.0    206
# 0.0     97
# Name: sex, dtype: int64

# %% [markdown]
# **cp = chest pain type**
#
#         -- Value 1: typical angina
#         -- Value 2: atypical angina
#         -- Value 3: non-anginal pain
#         -- Value 4: asymptomatic
#
# "a type of chest pain caused by reduced blood flow to the heart. Angina is a symptom of coronary artery disease. Angina is also called angina pectoris. Angina pain is often described as squeezing, pressure, heaviness, tightness or pain in the chest." (MayoClinic, https://www.mayoclinic.org/diseases-conditions/angina/symptoms-causes/syc-20369373#:~:text=Angina%20(an%2DJIE%2Dnuh,or%20pain%20in%20the%20chest.)

# %%
cleveland_data.cp.value_counts()
# angina less common and typical angina least common
# Out:
# 4.0    144
# 3.0     86
# 2.0     50
# 1.0     23
# Name: cp, dtype: int64

# %%
# trestbps = resting blood pressure
cleveland_data.trestbps.value_counts()
# another histogram candidate
# Out:
# 120.0    37
# 130.0    36
# 140.0    32
# 110.0    19
# 150.0    17
# 138.0    12
# 128.0    12
# 160.0    11
# 125.0    11
# 112.0     9
# 132.0     8
# 118.0     7
# 124.0     6
# 108.0     6
# 135.0     6
# 152.0     5
# 134.0     5
# 145.0     5
# 100.0     4
# 170.0     4
# 122.0     4
# 126.0     3
# 136.0     3
# 115.0     3
# 180.0     3
# 142.0     3
# 105.0     3
# 102.0     2
# 146.0     2
# 144.0     2
# 148.0     2
# 178.0     2
# 94.0      2
# 165.0     1
# 123.0     1
# 114.0     1
# 154.0     1
# 156.0     1
# 106.0     1
# 155.0     1
# 172.0     1
# 200.0     1
# 101.0     1
# 129.0     1
# 192.0     1
# 158.0     1
# 104.0     1
# 174.0     1
# 117.0     1
# 164.0     1
# Name: trestbps, dtype: int64

# %%
# cholesterol
cleveland_data.chol.value_counts()
# 152 categories! candidate for descretization
# Out:
# 204.0    6
# 197.0    6
# 234.0    6
# 269.0    5
# 212.0    5
#         ..
# 340.0    1
# 160.0    1
# 394.0    1
# 184.0    1
# 131.0    1
# Name: chol, Length: 152, dtype: int64

# %% [markdown]
# **fasting blood sugar**
#
# > 120 mg/dl (1 = true; 0 = false)
#
# "126 mg/dL or higher indicates you have diabetes" (CDC, https://www.cdc.gov/diabetes/basics/getting-tested.html#:~:text=A%20fasting%20blood%20sugar%20level,higher%20indicates%20you%20have%20diabetes.)

# %%
cleveland_data.fbs.value_counts()
# most people do not have diabetes
# Out:
# 0.0    258
# 1.0     45
# Name: fbs, dtype: int64

# %% [markdown]
# **restecg: resting electrocardiographic results**
#
#         -- Value 0: normal
#         -- Value 1: having ST-T wave abnormality (T wave inversions and/or ST
#                     elevation or depression of > 0.05 mV)
#         -- Value 2: showing probable or definite left ventricular hypertrophy
#                     by Estes' criteria
#
# "Left ventricular hypertrophy is a thickening of the wall of the heart's main pumping chamber. This thickening may result in elevation of pressure within the heart and sometimes poor pumping action. The most common cause is high blood pressure." (MayoClinic, https://www.mayoclinic.org/diseases-conditions/left-ventricular-hypertrophy/symptoms-causes/syc-20374314#:~:text=Left%20ventricular%20hypertrophy%20is%20a,cause%20is%20high%20blood%20pressure.)

# %%
cleveland_data.restecg.value_counts()
# half of people have normal results
# almost half of people show "probable or definite left ventricular hypertrophy"
# Out:
# 0.0    151
# 2.0    148
# 1.0      4
# Name: restecg, dtype: int64

# %%
# thalach = maximum heart rate achieved
cleveland_data.thalach.value_counts()
# 91 rows; also may be good for descretization
# Out:
# 162.0    11
# 160.0     9
# 163.0     9
# 152.0     8
# 150.0     7
#          ..
# 177.0     1
# 127.0     1
# 97.0      1
# 190.0     1
# 90.0      1
# Name: thalach, Length: 91, dtype: int64

# %%
# exang = exercise induced angina
cleveland_data.exang.value_counts()
# about a third of people experience
# Out:
# 0.0    204
# 1.0     99
# Name: exang, dtype: int64

# %% [markdown]
# **oldpeak = ST depression induced by exercise relative to rest**
#
# "ST depression refers to a finding on an electrocardiogram,[1][2] wherein the trace in the ST segment is abnormally low below the baseline." "It is often a sign of myocardial ischemia, of which coronary insufficiency is a major cause." (Wikipedia, https://en.wikipedia.org/wiki/ST_depression)

# %%
cleveland_data.oldpeak.value_counts()
# probably descretize
# Out:
# 0.0    99
# 1.2    17
# 0.6    14
# 1.0    14
# 1.4    13
# 0.8    13
# 0.2    12
# 1.6    11
# 1.8    10
# 2.0     9
# 0.4     9
# 0.1     7
# 2.8     6
# 2.6     6
# 1.9     5
# 0.5     5
# 3.0     5
# 1.5     5
# 3.6     4
# 2.2     4
# 3.4     3
# 0.9     3
# 2.4     3
# 0.3     3
# 4.0     3
# 1.1     2
# 4.2     2
# 2.3     2
# 2.5     2
# 3.2     2
# 5.6     1
# 2.9     1
# 6.2     1
# 2.1     1
# 1.3     1
# 3.1     1
# 3.8     1
# 0.7     1
# 3.5     1
# 4.4     1
# Name: oldpeak, dtype: int64

# %% [markdown]
# **slope: the slope of the peak exercise ST segment**
#
#         -- Value 1: upsloping
#         -- Value 2: flat
#         -- Value 3: downsloping
#
# "The ST segment/heart rate slope as a predictor of coronary artery disease: Comparison with quantitative thallium imaging and conventional ST segment criteria" (Finkelhor *et al.*, https://www.sciencedirect.com/science/article/abs/pii/0002870386902656)

# %%
cleveland_data.slope.value_counts()
# very few downsloping
# Out:
# 1.0    142
# 2.0    140
# 3.0     21
# Name: slope, dtype: int64

# %%
# ca: number of major vessels (0-3) colored by flourosopy
cleveland_data.ca.value_counts()
# 4 missing values
# Out:
# 0.0    176
# 1.0     65
# 2.0     38
# 3.0     20
# ?        4
# Name: ca, dtype: int64

# %% [markdown]
# **Thalassemia** (thal)
#
# - 3 = normal
# - 6 = fixed defect
# - 7 = reversable defect
#
# "an inherited blood disorder that causes your body to have less hemoglobin than normal. Hemoglobin enables red blood cells to carry oxygen. Thalassemia can cause anemia, leaving you fatigued. If you have mild thalassemia, you might not need treatment." (MayoClinic, https://www.mayoclinic.org/diseases-conditions/thalassemia/symptoms-causes/syc-20354995#:~:text=Thalassemia%20(thal%2Duh%2DSEE,you%20might%20not%20need%20treatment.)

# %%
cleveland_data.thal.value_counts()
# 2 missing values
# Out:
# 3.0    166
# 7.0    117
# 6.0     18
# ?        2
# Name: thal, dtype: int64

# %%
# TO GET THAL AND CA TO BEHAVE, NEED TO REMOVE "?" AND FROM OBJECT TO NUMERIC

cleveland_data_mod = cleveland_data
cleveland_data_mod['thal'].replace('?', np.NaN, inplace = True)
cleveland_data_mod['thal'] = cleveland_data_mod['thal'].astype(float)
cleveland_data_mod['ca'].replace('?', np.NaN, inplace = True)
cleveland_data_mod['ca'] = cleveland_data_mod['ca'].astype(float)
cleveland_data_mod.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.438944    0.679868    3.158416  131.689769  246.693069    0.148515
# std      9.038662    0.467299    0.960126   17.599748   51.776918    0.356198
# min     29.000000    0.000000    1.000000   94.000000  126.000000    0.000000
# 25%     48.000000    0.000000    3.000000  120.000000  211.000000    0.000000
# 50%     56.000000    1.000000    3.000000  130.000000  241.000000    0.000000
# 75%     61.000000    1.000000    4.000000  140.000000  275.000000    0.000000
# max     77.000000    1.000000    4.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  299.000000
# mean     0.990099  149.607261    0.326733    1.039604    1.600660    0.672241
# ...

# %% [markdown]
# **num: diagnosis of heart disease (angiographic disease status)**
#
#         -- Value 0: < 50% diameter narrowing
#         -- Value 1: > 50% diameter narrowing

# %% [markdown]
# **num = label**
#
# From dataset documentation:
# 4. Relevant Information:
#      This database contains 76 attributes, but all published experiments
#      refer to using a subset of 14 of them.  In particular, the Cleveland
#      database is the only one that has been used by ML researchers to
#      this date.  The "goal" field refers to the presence of heart disease
#      in the patient.  It is integer valued from 0 (no presence) to 4.
#      Experiments with the Cleveland database have concentrated on simply
#      attempting to distinguish presence (values 1,2,3,4) from absence (value
#      0).

# %%
cleveland_data.num.value_counts()
# option to do binary classification (as others have) and/or multiclass
# Out:
# 0    164
# 1     55
# 2     36
# 3     35
# 4     13
# Name: num, dtype: int64

# %% [markdown]
# ### HISTOGRAMS

# %%
cleveland_data[['age', 'trestbps', 'chol', 'thalach', 'oldpeak']].hist(bins = 50, figsize = (10,7.5))
#cleveland_data.hist(bins = 50, figsize = (10,7.5)) # all
plt.suptitle("Cleveland - main histograms", fontsize = 16)
plt.show
# AGE
#   most people middle age
#   no 53 year olds
#   symmetrical & mesokurtic?
# TRESTBPS
#   most measurements in units of 10
#   most measurements between 110 and 160
#   positively-skewed & platykurtic?
# CHOL
#   symmetric and leptokurtic (?), except for outlier above 500
# THALACH
#   negatively-skewed & mesokurtic?
# OLDPEAK
#   most values 0; otherwise, positively-skewed & platykurtic?
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# look at other attributes
cleveland_data[['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca', 'thal', 'num']].hist(figsize = (10,7.5))
plt.suptitle("Cleveland - other attributes", fontsize = 16)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# age skew & kurtosis (all data)
print("age: skew = ", sp.stats.skew(cleveland_data[['age']], bias = False),
      "& kurtosis = ", sp.stats.kurtosis(cleveland_data[['age']], bias = False))
print("trestbps: skew = ", sp.stats.skew(cleveland_data[['trestbps']], bias = False),
      "& kurtosis = ", sp.stats.kurtosis(cleveland_data[['trestbps']], bias = False))
print("chol: skew = ", sp.stats.skew(cleveland_data[['chol']], bias = False),
      "& kurtosis = ", sp.stats.kurtosis(cleveland_data[['chol']], bias = False))
print("thalach: skew = ", sp.stats.skew(cleveland_data[['thalach']], bias = False),
      "& kurtosis = ", sp.stats.kurtosis(cleveland_data[['thalach']], bias = False))
print("oldpeak: skew = ", sp.stats.skew(cleveland_data[['oldpeak']], bias = False),
      "& kurtosis = ", sp.stats.kurtosis(cleveland_data[['oldpeak']], bias = False))
# Out:
# age: skew =  [-0.20906047] & kurtosis =  [-0.52338275]
# trestbps: skew =  [0.70603465] & kurtosis =  [0.88007387]
# chol: skew =  [1.13550315] & kurtosis =  [4.49172429]
# thalach: skew =  [-0.53744867] & kurtosis =  [-0.05354096]
# oldpeak: skew =  [1.26971993] & kurtosis =  [1.57581307]

# %% [markdown]
# ## PATIENTS WITH HEART DISEASE

# %% [markdown]
# ### BASIC INFO

# %%
# subset of cleveland dataset with only heart disease positive patients
cleveland_positive = cleveland_data[cleveland_data['num'] > 0]
cleveland_positive.num.value_counts() # verify
# Out:
# 1    55
# 2    36
# 3    35
# 4    13
# Name: num, dtype: int64

# %%
# heart disease positive numeric statistics
cleveland_positive.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  139.000000  139.000000  139.000000  139.000000  139.000000  139.000000
# mean    56.625899    0.820144    3.589928  134.568345  251.474820    0.158273
# std      7.938416    0.385457    0.823680   18.769019   49.486835    0.366317
# min     35.000000    0.000000    1.000000  100.000000  131.000000    0.000000
# 25%     52.000000    1.000000    4.000000  120.000000  217.500000    0.000000
# 50%     58.000000    1.000000    4.000000  130.000000  249.000000    0.000000
# 75%     62.000000    1.000000    4.000000  145.000000  283.500000    0.000000
# max     77.000000    1.000000    4.000000  200.000000  409.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  139.000000  139.000000  139.000000  139.000000  139.000000  138.000000
# mean     1.172662  139.258993    0.546763    1.574101    1.827338    1.137681
# ...

# %%
# modify to get ca and thal columns
# (tried to make cleveland_positive from cleveland_mod and then describing, 
#  but wasn't getting result wanted)
cleveland_pos_mod = cleveland_positive
cleveland_pos_mod['thal'].replace('?', np.NaN, inplace = True)
cleveland_pos_mod['thal'] = cleveland_pos_mod['thal'].astype(float)
cleveland_pos_mod['ca'].replace('?', np.NaN, inplace = True)
cleveland_pos_mod['ca'] = cleveland_pos_mod['ca'].astype(float)
cleveland_pos_mod.describe()
# Out:
# <ipython-input-161-a1c0f7a6a150>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleveland_pos_mod['thal'].replace('?', np.NaN, inplace = True)
# <ipython-input-161-a1c0f7a6a150>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleveland_pos_mod['thal'] = cleveland_pos_mod['thal'].astype(float)
# <ipython-input-161-a1c0f7a6a150>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %% [markdown]
# ### HISTOGRAMS

# %%
# histograms of heart disease positive patients
#cleveland_positive.hist(bins = 50, figsize = (10,7.5)) # all
cleveland_positive[['age', 'trestbps', 'chol', 'thalach', 'oldpeak']].hist(bins = 50, figsize = (10,7.5))
plt.suptitle("Cleveland - HD Positive - main histograms", fontsize = 16)
plt.show
# for heart disease positive patients:
#   age distibution more negatively skewed
#   trestbps more positively skewed
#   chol more symmetrical
#   thalach distribution similar
#   oldpeak still has more 0s than any other single value, but more higher 
#      values and the highest values are higher
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# look at other categories
cleveland_positive[['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca', 'thal', 'num']].hist(figsize = (10,7.5))
plt.suptitle("Cleveland - HD Positive - other categories", fontsize = 16)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# age skew & kurtosis (heart disease positive data)
print("age: skew = ", sp.stats.skew(cleveland_positive[['age']], bias = False),
      "& kurtosis = ", sp.stats.kurtosis(cleveland_positive[['age']], bias = False))
print("trestbps: skew = ", sp.stats.skew(cleveland_positive[['trestbps']], bias = False),
      "& kurtosis = ", sp.stats.kurtosis(cleveland_positive[['trestbps']], bias = False))
print("chol: skew = ", sp.stats.skew(cleveland_positive[['chol']], bias = False),
      "& kurtosis = ", sp.stats.kurtosis(cleveland_positive[['chol']], bias = False))
print("thalach: skew = ", sp.stats.skew(cleveland_positive[['thalach']], bias = False),
      "& kurtosis = ", sp.stats.kurtosis(cleveland_positive[['thalach']], bias = False))
print("oldpeak: skew = ", sp.stats.skew(cleveland_positive[['oldpeak']], bias = False),
      "& kurtosis = ", sp.stats.kurtosis(cleveland_positive[['oldpeak']], bias = False))
# Out:
# age: skew =  [-0.55815153] & kurtosis =  [0.15049712]
# trestbps: skew =  [0.83432673] & kurtosis =  [0.83609226]
# chol: skew =  [0.29911266] & kurtosis =  [0.34124962]
# thalach: skew =  [-0.30934856] & kurtosis =  [-0.19877598]
# oldpeak: skew =  [0.74554298] & kurtosis =  [0.40495027]

# %% [markdown]
# ## PATIENTS WITHOUT HEART DISEASE

# %% [markdown]
# ### BASIC INFO

# %%
# subset of cleveland dataset with only heart disease negative patients
cleveland_negative = cleveland_data[cleveland_data['num'] == 0]
cleveland_negative.num.value_counts() # verify
# Out:
# 0    164
# Name: num, dtype: int64

# %%
# heart disease negative numeric statistics
# modify to get ca and thal columns
cleveland_neg_mod = cleveland_negative
cleveland_neg_mod['thal'].replace('?', np.NaN, inplace = True)
cleveland_neg_mod['thal'] = cleveland_neg_mod['thal'].astype(float)
cleveland_neg_mod['ca'].replace('?', np.NaN, inplace = True)
cleveland_neg_mod['ca'] = cleveland_neg_mod['ca'].astype(float)
cleveland_neg_mod.describe()
# Out:
# <ipython-input-166-e2724d71f66a>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleveland_neg_mod['thal'].replace('?', np.NaN, inplace = True)
# <ipython-input-166-e2724d71f66a>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleveland_neg_mod['thal'] = cleveland_neg_mod['thal'].astype(float)
# <ipython-input-166-e2724d71f66a>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %% [markdown]
# ### HISTOGRAMS

# %%
# histograms of heart disease negative patients
#cleveland_negative.hist(bins = 50, figsize = (10,7.5)) # all
cleveland_negative[['age', 'trestbps', 'chol', 'thalach', 'oldpeak']].hist(bins = 50, figsize = (10,7.5))
plt.suptitle("Cleveland - HD Negative - main histograms", fontsize = 16)
plt.show
# for heart disease negative patients:
#   age more symmetrical
#   trestbps more symmetrical
#   chol more positively skewed
#      (the cholesterol outlier is heart disease negative)
#   thalach distribution similar
#   oldpeak values predominantly 0
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# look at other categories
cleveland_negative[['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca', 'thal', 'num']].hist(figsize = (10,7.5))
plt.suptitle("Cleveland - HD Negative - other categories", fontsize = 16)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# age skew & kurtosis (heart disease negative data)
print("age: skew = ", sp.stats.skew(cleveland_negative[['age']], bias = False),
      "& kurtosis = ", sp.stats.kurtosis(cleveland_negative[['age']], bias = False))
print("trestbps: skew = ", sp.stats.skew(cleveland_negative[['trestbps']], bias = False),
      "& kurtosis = ", sp.stats.kurtosis(cleveland_negative[['trestbps']], bias = False))
print("chol: skew = ", sp.stats.skew(cleveland_negative[['chol']], bias = False),
      "& kurtosis = ", sp.stats.kurtosis(cleveland_negative[['chol']], bias = False))
print("thalach: skew = ", sp.stats.skew(cleveland_negative[['thalach']], bias = False),
      "& kurtosis = ", sp.stats.kurtosis(cleveland_negative[['thalach']], bias = False))
print("oldpeak: skew = ", sp.stats.skew(cleveland_negative[['oldpeak']], bias = False),
      "& kurtosis = ", sp.stats.kurtosis(cleveland_negative[['oldpeak']], bias = False))
# Out:
# age: skew =  [0.11695569] & kurtosis =  [-0.59980127]
# trestbps: skew =  [0.43338672] & kurtosis =  [0.39426456]
# chol: skew =  [1.75500833] & kurtosis =  [7.71408964]
# thalach: skew =  [-0.698025] & kurtosis =  [0.44908444]
# oldpeak: skew =  [1.63898027] & kurtosis =  [3.16134784]

# %%
# look at other categories
cleveland_negative[['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca', 'thal', 'num']].hist(figsize = (10,7.5))
plt.suptitle("Cleveland - HD Negative - other categories", fontsize = 16)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## WITH AND WITHOUT HEART DISEASE - BY SEX

# %%
cleveland_data.groupby('sex').num.value_counts()
# larger fraction of men heart disease positive
# most women heart disease negative
# Out:
# sex  num
# 0.0  0      72
#      1       9
#      2       7
#      3       7
#      4       2
# 1.0  0      92
#      1      46
#      2      29
#      3      28
#      4      11
# Name: num, dtype: int64

# %% [markdown]
# # SWITZERLAND, VA, & HUNGARIAN

# %% [markdown]
# Note: The original model building with Cleveland dataset may help determine which attributes to keep in the combined dataset.

# %% [markdown]
# ## SWITZERLAND

# %% [markdown]
# ### BASIC INFO

# %%
switzerland_data.head()
# Out:
#    age  sex  cp trestbps  chol fbs restecg thalach exang oldpeak slope ca  \
# 0   32    1   1       95     0   ?       0     127     0      .7     1  ?
# 1   34    1   4      115     0   ?       ?     154     0      .2     1  ?
# 2   35    1   4        ?     0   ?       0     130     1       ?     ?  ?
# 3   36    1   4      110     0   ?       0     125     1       1     2  ?
# 4   38    0   4      105     0   ?       0     166     0     2.8     1  ?
#
#   thal  num
# 0    ?    1
# 1    ?    1
# 2    7    3
# 3    6    1
# 4    ?    2

# %%
# replace "?" with NaN
switzerland_mod = switzerland_data
switzerland_mod = switzerland_mod.replace('?', np.NaN)
switzerland_mod.head()
# Out:
#    age  sex  cp trestbps  chol  fbs restecg thalach exang oldpeak slope   ca  \
# 0   32    1   1       95     0  NaN       0     127     0      .7     1  NaN
# 1   34    1   4      115     0  NaN     NaN     154     0      .2     1  NaN
# 2   35    1   4      NaN     0  NaN       0     130     1     NaN   NaN  NaN
# 3   36    1   4      110     0  NaN       0     125     1       1     2  NaN
# 4   38    0   4      105     0  NaN       0     166     0     2.8     1  NaN
#
#   thal  num
# 0  NaN    1
# 1  NaN    1
# 2    7    3
# 3    6    1
# 4  NaN    2

# %%
switzerland_mod.astype(float).describe()
# Out:
#               age         sex          cp    trestbps   chol        fbs  \
# count  123.000000  123.000000  123.000000  121.000000  123.0  48.000000
# mean    55.317073    0.918699    3.699187  130.206612    0.0   0.104167
# std      9.032108    0.274414    0.688726   22.559151    0.0   0.308709
# min     32.000000    0.000000    1.000000   80.000000    0.0   0.000000
# 25%     51.000000    1.000000    4.000000  115.000000    0.0   0.000000
# 50%     56.000000    1.000000    4.000000  125.000000    0.0   0.000000
# 75%     61.500000    1.000000    4.000000  145.000000    0.0   0.000000
# max     74.000000    1.000000    4.000000  200.000000    0.0   1.000000
#
#           restecg     thalach       exang     oldpeak       slope        ca  \
# count  122.000000  122.000000  122.000000  117.000000  106.000000  5.000000
# mean     0.360656  121.557377    0.442623    0.653846    1.801887  1.600000
# std      0.590077   25.977438    0.498745    1.056061    0.623658  0.547723
# ...

# %%
# info with NaN
# (info with "?" show no missing values)
switzerland_mod.info()
# most ca values missing
# more than half of fbs missing
# almost half of thal missing
# other values mostly complete, including oldpeak and slope which may
#     be of interest for prediction (see previous reference)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123 entries, 0 to 122
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       123 non-null    int64
#  1   sex       123 non-null    int64
#  2   cp        123 non-null    int64
#  3   trestbps  121 non-null    object
#  4   chol      123 non-null    int64
#  5   fbs       48 non-null     object
#  6   restecg   122 non-null    object
#  7   thalach   122 non-null    object
#  8   exang     122 non-null    object
#  9   oldpeak   117 non-null    object
#  10  slope     106 non-null    object
#  11  ca        5 non-null      object
#  12  thal      71 non-null     object
#  13  num       123 non-null    int64
# dtypes: int64(5), object(9)
# memory usage: 13.6+ KB

# %%
switzerland_data.num.value_counts()
# Out:
# 1    48
# 2    32
# 3    30
# 0     8
# 4     5
# Name: num, dtype: int64

# %% [markdown]
# ### HISTOGRAMS

# %%
# look at all the histograms for high level look (instead of all value_counts)
#switzerland_mod.astype(float).hist(bins = 50, figsize = (20,15))
#plt.show
# vast majority of patients male in dataset

# %%
# focused look at histograms
switzerland_mod[['age', 'trestbps', 'chol', 'thalach', 'oldpeak']].astype(float).hist(bins = 50, figsize = (10,7.5))
plt.suptitle("Switzerland - main histograms", fontsize = 16)
plt.show
# cholesterol meaningless in this dataset (all = 0)
# negative oldpeak values versus cleveland dataset
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# look at other attributes
switzerland_mod[['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca', 'thal', 'num']].astype(float).hist(figsize = (10,7.5))
plt.suptitle("Switzerland - other attributes", fontsize = 16)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## VA

# %% [markdown]
# ### BASIC INFO

# %%
va_data.head()
# Out:
#    age  sex  cp trestbps chol fbs  restecg thalach exang oldpeak slope ca  \
# 0   63    1   4      140  260   0        1     112     1       3     2  ?
# 1   44    1   4      130  209   0        1     127     0       0     ?  ?
# 2   60    1   4      132  218   0        1     140     1     1.5     3  ?
# 3   55    1   4      142  228   0        1     149     1     2.5     1  ?
# 4   66    1   3      110  213   1        2      99     1     1.3     2  ?
#
#   thal  num
# 0    ?    2
# 1    ?    0
# 2    ?    2
# 3    ?    1
# 4    ?    0

# %%
# replace "?" with NaN
va_data_mod = va_data
va_data_mod = va_data_mod.replace('?', np.NaN)
va_data_mod.head()
# Out:
#    age  sex  cp trestbps chol fbs  restecg thalach exang oldpeak slope   ca  \
# 0   63    1   4      140  260   0        1     112     1       3     2  NaN
# 1   44    1   4      130  209   0        1     127     0       0   NaN  NaN
# 2   60    1   4      132  218   0        1     140     1     1.5     3  NaN
# 3   55    1   4      142  228   0        1     149     1     2.5     1  NaN
# 4   66    1   3      110  213   1        2      99     1     1.3     2  NaN
#
#   thal  num
# 0  NaN    2
# 1  NaN    0
# 2  NaN    2
# 3  NaN    1
# 4  NaN    0

# %%
va_data_mod.astype(float).describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  200.000000  200.000000  200.000000  144.000000  193.000000  193.000000
# mean    59.350000    0.970000    3.505000  133.763889  178.746114    0.352332
# std      7.811697    0.171015    0.795701   21.537733  114.035232    0.478939
# min     35.000000    0.000000    1.000000    0.000000    0.000000    0.000000
# 25%     55.000000    1.000000    3.000000  120.000000    0.000000    0.000000
# 50%     60.000000    1.000000    4.000000  130.000000  216.000000    0.000000
# 75%     64.000000    1.000000    4.000000  147.000000  258.000000    1.000000
# max     77.000000    1.000000    4.000000  190.000000  458.000000    1.000000
#
#           restecg     thalach       exang     oldpeak      slope   ca  \
# count  200.000000  147.000000  147.000000  144.000000  98.000000  2.0
# mean     0.735000  122.795918    0.646259    1.320833   2.132653  0.0
# ...

# %%
va_data_mod.info()
# again very few ca or thal values
# half of slope values are missing (may be important predictor - see prev ref)
# quarter of data missing from multiple other attributes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       200 non-null    int64
#  1   sex       200 non-null    int64
#  2   cp        200 non-null    int64
#  3   trestbps  144 non-null    object
#  4   chol      193 non-null    object
#  5   fbs       193 non-null    object
#  6   restecg   200 non-null    int64
#  7   thalach   147 non-null    object
#  8   exang     147 non-null    object
#  9   oldpeak   144 non-null    object
#  10  slope     98 non-null     object
#  11  ca        2 non-null      object
#  12  thal      34 non-null     object
#  13  num       200 non-null    int64
# dtypes: int64(5), object(9)
# memory usage: 22.0+ KB

# %%
va_data.num.value_counts()
# Out:
# 1    56
# 0    51
# 3    42
# 2    41
# 4    10
# Name: num, dtype: int64

# %% [markdown]
# ### HISTOGRAMS

# %%
# look at all the histograms for high level look (instead of all value_counts)
#va_data_mod.astype(float).hist(bins = 50, figsize = (20,15))
#plt.show
# most dramatic difference in sex of patients of any of the datasets
# many 0 cholesterol values
# 0 trestbps value

# %%
# focused look at histograms
va_data_mod[['age', 'trestbps', 'chol', 'thalach', 'oldpeak']].astype(float).hist(bins = 50, figsize = (10,7.5))
plt.suptitle("VA - main histograms", fontsize = 16)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# look at other attributes
va_data_mod[['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca', 'thal', 'num']].astype(float).hist(figsize = (10,7.5))
plt.suptitle("VA - other attributes", fontsize = 16)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # HUNGARIAN

# %% [markdown]
# ## BASIC INFO

# %%
# take a peak
hungarian_data.head()
# Out:
#     age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0  40.0  1.0  2.0     140.0  289.0  0.0      0.0    172.0    0.0      0.0
# 1  49.0  0.0  3.0     160.0  180.0  0.0      0.0    156.0    0.0      1.0
# 2  37.0  1.0  2.0     130.0  283.0  0.0      1.0     98.0    0.0      0.0
# 3  48.0  0.0  4.0     138.0  214.0  0.0      0.0    108.0    1.0      1.5
# 4  54.0  1.0  3.0     150.0   -9.0  0.0      0.0    122.0    0.0      0.0
#
#    slope   ca  thal  num
# 0   -9.0 -9.0  -9.0  0.0
# 1    2.0 -9.0  -9.0  1.0
# 2   -9.0 -9.0  -9.0  0.0
# 3    2.0 -9.0  -9.0  3.0
# 4   -9.0 -9.0  -9.0  0.0

# %%
hungarian_data.replace(-9.0, np.NaN).describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  294.000000  294.000000  294.000000  293.000000  271.000000  286.000000
# mean    47.826531    0.724490    2.982993  132.583618  250.848708    0.069930
# std      7.811812    0.447533    0.965117   17.626568   67.657711    0.255476
# min     28.000000    0.000000    1.000000   92.000000   85.000000    0.000000
# 25%     42.000000    0.000000    2.000000  120.000000  209.000000    0.000000
# 50%     49.000000    1.000000    3.000000  130.000000  243.000000    0.000000
# 75%     54.000000    1.000000    4.000000  140.000000  282.500000    0.000000
# max     66.000000    1.000000    4.000000  200.000000  603.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope    ca  \
# count  293.000000  293.000000  293.000000  294.000000  104.000000  4.00
# mean     0.218430  139.129693    0.303754    0.586054    1.894231  2.25
# ...

# %%
hungarian_data.replace(-9.0, np.NaN).info()
# ca has very little data
# thal also has very little data and probably should be excluded too
# slope is missing most too, but it may be a valuable predictor
#    (see earlier reference)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 295 entries, 0 to 294
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       294 non-null    float64
#  1   sex       294 non-null    float64
#  2   cp        294 non-null    float64
#  3   trestbps  293 non-null    float64
#  4   chol      271 non-null    float64
#  5   fbs       286 non-null    float64
#  6   restecg   293 non-null    float64
#  7   thalach   293 non-null    float64
#  8   exang     293 non-null    float64
#  9   oldpeak   294 non-null    float64
#  10  slope     104 non-null    float64
#  11  ca        4 non-null      float64
#  12  thal      28 non-null     float64
#  13  num       294 non-null    float64
# dtypes: float64(14)
# memory usage: 32.4 KB

# %%
hungarian_data.num.value_counts()
# Out:
# 0.0    188
# 1.0     37
# 3.0     28
# 2.0     26
# 4.0     15
# Name: num, dtype: int64

# %% [markdown]
# ## HISTOGRAMS

# %% [markdown]
# ### PATIENTS WITH AND WITHOUT HEART DISEASE

# %%
# look at all the histograms for high level look (instead of all value_counts)
#hungarian_data.hist(bins = 50, figsize = (20,15))
#plt.show

# %%
# focused look at histograms
hungarian_data[['age', 'trestbps', 'chol', 'thalach', 'oldpeak']].hist(bins = 50, figsize = (10,7.5))
plt.suptitle("Hungarian - main histograms", fontsize = 16)
plt.show
# odd pattern in age histogram
# negative trestbps & thalach outliers
# large number of 0 cholesterols (could fill in with mean if keep attribute)
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# look at other attributes
hungarian_data[['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca', 'thal', 'num']].hist(figsize = (10,7.5))
plt.suptitle("Hungarian - other attributes", fontsize = 16)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### PATIENTS WITH HEART DISEASE

# %%
# subset of hungarian dataset with only heart disease positive patients
hungarian_positive = hungarian_data[hungarian_data['num'] > 0]
hungarian_positive.num.value_counts() # verify
# Out:
# 1.0    37
# 3.0    28
# 2.0    26
# 4.0    15
# Name: num, dtype: int64

# %%
# histograms of heart disease positive patients
hungarian_positive[['age', 'trestbps', 'chol', 'thalach', 'oldpeak']].hist(bins = 50, figsize = (10,7.5))
plt.suptitle("Hungarian - HD Positive - main histograms", fontsize = 16)
plt.show
# for heart disease positive patients:
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# look at other categories
hungarian_positive[['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca', 'thal', 'num']].hist(figsize = (10,7.5))
plt.suptitle("Hungarian - HD Positive - other categories", fontsize = 16)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### PATIENTS WITHOUT HEART DISEASE

# %%
# subset of hungarian dataset with only heart disease negative patients
hungarian_negative = hungarian_data[hungarian_data['num'] == 0]
hungarian_negative.num.value_counts() # verify
# Out:
# 0.0    188
# Name: num, dtype: int64

# %%
# histograms of heart disease negative patients
hungarian_negative[['age', 'trestbps', 'chol', 'thalach', 'oldpeak']].hist(bins = 50, figsize = (10,7.5))
plt.suptitle("Hungarian - HD Negative - main histograms", fontsize = 16)
plt.show
# for heart disease negative patients:
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# look at other categories
hungarian_negative[['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca', 'thal', 'num']].hist(figsize = (10,7.5))
plt.suptitle("Hungarian - HD Negative - other categories", fontsize = 16)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # STATLOG

# %% [markdown]
# ## ALL DATA

# %% [markdown]
# ### BASIC INFO

# %%
statlog_data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a5394e896285> in <module>
# ----> 1 statlog_data.head()
#
# NameError: name 'statlog_data' is not defined

# %%
statlog_data.info()

# %%
statlog_data.describe()

# %% [markdown]
# ### HISTOGRAMS

# %%
# focused look at histograms
statlog_data[['age', 'trestbps', 'chol', 'thalach', 'oldpeak']].hist(bins = 50, figsize = (10,7.5))
plt.suptitle("Statlog - main histograms", fontsize = 16)
plt.show
# positive skew of trestbps (outliers above 180)
# cholesterol outlier above 500
# negative skew of thalach (outlier below 75)

# %%
# age skew & kurtosis (all data)
print("age: skew = ", sp.stats.skew(statlog_data[['age']], bias = False),
      "& kurtosis = ", sp.stats.kurtosis(statlog_data[['age']], bias = False))
print("trestbps: skew = ", sp.stats.skew(statlog_data[['trestbps']], bias = False),
      "& kurtosis = ", sp.stats.kurtosis(statlog_data[['trestbps']], bias = False))
print("chol: skew = ", sp.stats.skew(statlog_data[['chol']], bias = False),
      "& kurtosis = ", sp.stats.kurtosis(statlog_data[['chol']], bias = False))
print("thalach: skew = ", sp.stats.skew(statlog_data[['thalach']], bias = False),
      "& kurtosis = ", sp.stats.kurtosis(statlog_data[['thalach']], bias = False))
print("oldpeak: skew = ", sp.stats.skew(statlog_data[['oldpeak']], bias = False),
      "& kurtosis = ", sp.stats.kurtosis(statlog_data[['oldpeak']], bias = False))

# %%
# other categories
statlog_data[['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca', 'thal', 'num']].hist(figsize = (10,7.5))
plt.suptitle("Statlog - other attributes", fontsize = 16)
plt.show
# gender distribution closer to cleveland dataset's

# %% [markdown]
# ## PATIENTS WITH VS WITHOUT HEART DISEASE

# %% [markdown]
# ### BASIC INFO

# %%
# heart disease negative ('num' == 1)
statlog_data[statlog_data['num'] == 1].describe()
# 150 negative
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  150.000000  150.000000  150.000000  150.000000  150.000000  150.000000
# mean    52.706667    0.553333    2.820000  128.866667  244.213333    0.153333
# std      9.509830    0.498813    0.927362   16.457660   54.019085    0.361516
# min     29.000000    0.000000    1.000000   94.000000  126.000000    0.000000
# 25%     45.000000    0.000000    2.000000  120.000000  209.000000    0.000000
# 50%     52.000000    1.000000    3.000000  130.000000  236.000000    0.000000
# 75%     59.000000    1.000000    3.750000  140.000000  268.750000    0.000000
# max     76.000000    1.000000    4.000000  180.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  150.000000  150.000000  150.000000  150.000000  150.000000  150.000000
# mean     0.860000  158.333333    0.153333    0.622667    1.400000    0.286667
# ...

# %%
# heart disease positive ('num' == 2)
statlog_data[statlog_data['num'] == 2].describe()
# 120 positive
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  120.000000  120.000000  120.000000  120.000000  120.000000  120.000000
# mean    56.591667    0.833333    3.616667  134.441667  256.466667    0.141667
# std      8.116273    0.374241    0.779823   19.095424   47.969166    0.350170
# min     35.000000    0.000000    1.000000  100.000000  149.000000    0.000000
# 25%     52.000000    1.000000    4.000000  120.000000  227.250000    0.000000
# 50%     58.000000    1.000000    4.000000  130.000000  255.500000    0.000000
# 75%     62.000000    1.000000    4.000000  145.000000  286.500000    0.000000
# max     77.000000    1.000000    4.000000  200.000000  409.000000    1.000000
#
#          restecg     thalach      exang     oldpeak       slope          ca  \
# count  120.00000  120.000000  120.00000  120.000000  120.000000  120.000000
# mean     1.22500  138.858333    0.55000    1.584167    1.816667    1.150000
# ...

# %% [markdown]
# ### HISTOGRAMS

# %% [markdown]
# #### PATIENTS WITH HEART DISEASE

# %%
# focused look at histograms
statlog_pos = statlog_data
statlog_pos = statlog_pos[statlog_pos['num'] == 2]
statlog_pos[['age', 'trestbps', 'chol', 'thalach', 'oldpeak']].hist(bins = 50, figsize = (10,7.5))
plt.suptitle("Statlog - HD Positive - main histograms", fontsize = 16)
plt.show
# age more positively skewed
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# age skew & kurtosis (positive data)
print("age: skew = ", sp.stats.skew(statlog_pos[['age']], bias = False),
      "& kurtosis = ", sp.stats.kurtosis(statlog_pos[['age']], bias = False))
print("trestbps: skew = ", sp.stats.skew(statlog_pos[['trestbps']], bias = False),
      "& kurtosis = ", sp.stats.kurtosis(statlog_pos[['trestbps']], bias = False))
print("chol: skew = ", sp.stats.skew(statlog_pos[['chol']], bias = False),
      "& kurtosis = ", sp.stats.kurtosis(statlog_pos[['chol']], bias = False))
print("thalach: skew = ", sp.stats.skew(statlog_pos[['thalach']], bias = False),
      "& kurtosis = ", sp.stats.kurtosis(statlog_pos[['thalach']], bias = False))
print("oldpeak: skew = ", sp.stats.skew(statlog_pos[['oldpeak']], bias = False),
      "& kurtosis = ", sp.stats.kurtosis(statlog_pos[['oldpeak']], bias = False))
# Out:
# age: skew =  [-0.54629835] & kurtosis =  [0.12564137]
# trestbps: skew =  [0.8886235] & kurtosis =  [0.96280272]
# chol: skew =  [0.29618983] & kurtosis =  [0.53481879]
# thalach: skew =  [-0.24519435] & kurtosis =  [-0.318171]
# oldpeak: skew =  [0.77628593] & kurtosis =  [0.71925463]

# %%
# other categories
statlog_pos[['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca', 'thal', 'num']].hist(figsize = (10,7.5))
plt.suptitle("Statlog - HD Positive - other attributes", fontsize = 16)
plt.rcParams["figure.autolayout"] = True
plt.show
# more men than women heart disease positive
# most chest pain type 4
# most slope values 2
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #### PATIENTS WITHOUT HEART DISEASE

# %%
# focused look at histograms
statlog_neg = statlog_data
statlog_neg = statlog_neg[statlog_neg['num'] == 1]
statlog_neg[['age', 'trestbps', 'chol', 'thalach', 'oldpeak']].hist(bins = 50, figsize = (10,7.5))
plt.suptitle("Statlog - HD Negative - main histograms", fontsize = 16)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# age skew & kurtosis (negative data)
print("age: skew = ", sp.stats.skew(statlog_neg[['age']], bias = False),
      "& kurtosis = ", sp.stats.kurtosis(statlog_neg[['age']], bias = False))
print("trestbps: skew = ", sp.stats.skew(statlog_neg[['trestbps']], bias = False),
      "& kurtosis = ", sp.stats.kurtosis(statlog_neg[['trestbps']], bias = False))
print("chol: skew = ", sp.stats.skew(statlog_neg[['chol']], bias = False),
      "& kurtosis = ", sp.stats.kurtosis(statlog_neg[['chol']], bias = False))
print("thalach: skew = ", sp.stats.skew(statlog_neg[['thalach']], bias = False),
      "& kurtosis = ", sp.stats.kurtosis(statlog_neg[['thalach']], bias = False))
print("oldpeak: skew = ", sp.stats.skew(statlog_neg[['oldpeak']], bias = False),
      "& kurtosis = ", sp.stats.kurtosis(statlog_neg[['oldpeak']], bias = False))
# Out:
# age: skew =  [0.1563453] & kurtosis =  [-0.58143015]
# trestbps: skew =  [0.41352706] & kurtosis =  [0.26136044]
# chol: skew =  [1.78275981] & kurtosis =  [7.90536523]
# thalach: skew =  [-0.67740944] & kurtosis =  [0.47173452]
# oldpeak: skew =  [1.55621856] & kurtosis =  [2.81171733]

# %%
# other categories
statlog_neg[['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca', 'thal', 'num']].hist(figsize = (10,7.5))
plt.suptitle("Statlog - HD Negative - other attributes", fontsize = 16)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # ADDITIONAL

# %% [markdown]
# ## PLOTTING

# %%
colhead = list(cleveland_data.columns.values)

for header in colhead:
  fig, ax=plt.subplots(figsize = (8,6))
  indexval = list(cleveland_data[header].value_counts().index)
  valcount = list(cleveland_data[header].value_counts())
  ax.pie(valcount, labels=indexval, autopct = '%1.1f%%',  startangle = 110, labeldistance =1.1)
  ax.axis("equal")
  plt.legend()
  plt.title(header, fontsize = 40)
  plt.show()

# %% [markdown]
# ## STATISTICS

# %% [markdown]
# ### HISTOGRAMS

# %% [markdown]
# #### DATA PREPROCESSING

# %% [markdown]
# ##### SUFFIX TO COLUMN NAMES - COMBINED WIDE

# %%
# add suffix to column names
cleveland_suff = cleveland_data_mod.copy()
cleveland_suff = cleveland_suff.add_suffix('_cl')
#cleveland_suff.head() # to verify

# %%
# add suffix to column names
hungarian_suff = hungarian_data.copy()
hungarian_suff = hungarian_suff.add_suffix('_hu')
#hungarian_suff.head() # to verify

# %%
# add suffix to column names
switzerland_suff = switzerland_mod.copy()
switzerland_suff = switzerland_suff.add_suffix('_sw')
#switzerland_suff.head() # to verify

# %%
# add suffix to column names
va_suff = va_data_mod.copy()
va_suff = va_suff.add_suffix('_va')
#va_suff.head() # to verify

# %%
# wide combined dataset with column name suffix identifying original dataset
combined_wide = pd.concat((cleveland_suff, hungarian_suff, switzerland_suff, va_suff), axis=1)
combined_wide.head() # to verify

# %%
# only heart disease negative - with suffix
cleveland_suff_wo = cleveland_suff[cleveland_suff['num_cl'] == 0]
hungarian_suff_wo = hungarian_suff[hungarian_suff['num_hu'] == 0]
switzerland_suff_wo = switzerland_suff[switzerland_suff['num_sw'] == 0]
va_suff_wo = va_suff[va_suff['num_va'] == 0]
# combined dataset
combined_wide_wo = pd.concat((cleveland_suff_wo, hungarian_suff_wo, switzerland_suff_wo, va_suff_wo), axis = 1)

# %%
#combined_wide_wo.sample(10) # take a peek

# %%
# only heart disease positive - with suffix
cleveland_suff_with = cleveland_suff[cleveland_suff['num_cl'] > 0]
hungarian_suff_with = hungarian_suff[hungarian_suff['num_hu'] > 0]
switzerland_suff_with = switzerland_suff[switzerland_suff['num_sw'] > 0]
va_suff_with = va_suff[va_suff['num_va'] > 0]
# combined dataset
combined_wide_with = pd.concat((cleveland_suff_with, hungarian_suff_with, switzerland_suff_with, va_suff_with), axis = 1)

# %%
#combined_wide_with.sample(10) # take a peek

# %% [markdown]
# ##### NO SUFFIX - COMBINED LONG

# %%
cleveland_wo = cleveland_data_mod[cleveland_data_mod['num'] == 0]
cleveland_with = cleveland_data_mod[cleveland_data_mod['num'] > 0]
cleveland_data_mod.value_counts('num')
# Out:
# num
# 0    164
# 1     55
# 2     36
# 3     35
# 4     13
# dtype: int64

# %%
hungarian_wo = hungarian_data[hungarian_data['num'] == 0]
hungarian_with = hungarian_data[hungarian_data['num'] > 0]
hungarian_data.value_counts('num')
# Out:
# num
# 0.0    188
# 1.0     37
# 3.0     28
# 2.0     26
# 4.0     15
# dtype: int64

# %%
switzerland_wo = switzerland_data[switzerland_data['num'] == 0]
switzerland_with = switzerland_data[switzerland_data['num'] > 0]
switzerland_data.value_counts('num')
# Out:
# num
# 1    48
# 2    32
# 3    30
# 0     8
# 4     5
# dtype: int64

# %%
va_wo = va_data[va_data['num'] == 0]
va_with = va_data[va_data['num'] > 0]

# %%
combined_long_wo = pd.concat((cleveland_wo, hungarian_wo, switzerland_wo, va_wo), axis = 0)
combined_long_with = pd.concat((cleveland_with, hungarian_with, switzerland_with, va_with), axis = 0)

# %%
# to verify
combined_long_with.value_counts('num')
# Out:
# num
# 1.0    196
# 2.0    135
# 3.0    135
# 4.0     43
# dtype: int64

# %% [markdown]
# #### WITH AND WITHOUT HEART DISEASE

# %%
combined_wide[combined_wide.columns[combined_wide.columns.str.startswith('age')]].astype(float).hist(bins = 50, figsize = (10,7.5))
#plt.suptitle('test')
plt.show

# %%
va_data_mod[['age', 'trestbps', 'chol', 'thalach', 'oldpeak']].astype(float).hist(bins = 50, figsize = (10,7.5))
plt.suptitle("VA - main histograms", fontsize = 16)
plt.show

# %% [markdown]
# #### WITH VS WITHOUT HEART DISEASE

# %%
combined_long_with.thalach.value_counts()
# Out:
# ?        35
# 150.0    18
# 120      17
# 130.0    12
# 140      12
#          ..
# 119.0     1
# 180.0     1
# 82.0      1
# 121.0     1
# 159       1
# Name: thalach, Length: 167, dtype: int64

# %%
combined_long_with[['age', 'trestbps', 'chol', 'thalach', 'oldpeak']].astype(float).hist(bins = 50, figsize = (10,7.5))
#plt.suptitle('test')
plt.show

# %% [markdown]
# ### SEX

# %%
cleveland_sex = cleveland_data[['sex']]
cleveland_sex = cleveland_sex.rename({'sex':'cleveland'}, axis=1)
hungarian_sex = hungarian_data[['sex']]
hungarian_sex = hungarian_sex.rename({'sex':'hungarian'}, axis=1)
switzerland_sex = switzerland_data[['sex']]
switzerland_sex = switzerland_sex.rename({'sex':'switzerland'}, axis=1)
va_sex = va_data[['sex']]
va_sex = va_sex.rename({'sex':'va'}, axis=1)
combined_sex = pd.concat([cleveland_sex, hungarian_sex, switzerland_sex, va_sex], axis=1)

# %%
combined_sex.apply(pd.Series.value_counts).plot.bar(subplots=True, title=("","","",""), layout=(1,4), figsize=(12,3))
# Out:
# array([[<Axes: >, <Axes: >, <Axes: >, <Axes: >]], dtype=object)

# %%
cleveland_data.sex.value_counts()
